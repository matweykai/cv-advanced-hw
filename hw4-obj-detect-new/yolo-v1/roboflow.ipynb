# %%
# !uv pip install roboflow
# Out:
# Using Python 3.11.10 environment at: /Users/jamakase/Projects/univ/itmo/cv-adv/cv-advanced-hw/hw4-object-detection/.venv
# Resolved 24 packages in 680ms
# ⠙ Preparing packages... (0/4)
# ⠙ Preparing packages... (0/4)----     0 B/65.27 KiB
# ⠙ Preparing packages... (0/4)---- 14.89 KiB/65.27 KiB
# ⠙ Preparing packages... (0/4)---- 30.89 KiB/65.27 KiB
# ⠙ Preparing packages... (0/4)---- 46.89 KiB/65.27 KiB
# ⠙ Preparing packages... (0/4)- 62.89 KiB/65.27 KiB
# idna       ------------------------------ 62.89 KiB/65.27 KiB
# ⠙ Preparing packages... (0/4)-----     0 B/3.80 MiB
# idna       ------------------------------ 62.89 KiB/65.27 KiB
# roboflow   ------------------------------     0 B/83.27 KiB
# ⠙ Preparing packages... (0/4)-----     0 B/3.80 MiB
# idna       ------------------------------ 65.27 KiB/65.27 KiB
# roboflow   ------------------------------     0 B/83.27 KiB
# ⠙ Preparing packages... (0/4)-----     0 B/3.80 MiB
# ...

# %%
from roboflow import Roboflow
import os

# Initialize Roboflow
rf = Roboflow(api_key="")

# Access the project
project = rf.workspace("artem-astapenko-7tupn").project("pig-test-10q6c")
dataset = project.version(2).download("voc", location="./data")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ./data in voc:: 100%|██████████| 244/244 [00:00<00:00, 2569.59it/s]
